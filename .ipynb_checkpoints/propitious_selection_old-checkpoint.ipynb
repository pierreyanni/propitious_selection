# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
class Propitious:
    def __init__(self, w, alpha1, alpha2, L1, L2, beta=0.8, eps=0.8):
        self.w = w
        self.alpha1 = alpha1
        self.alpha2 = alpha2
        self.L1 = L1
        self.L2 = L2
        self.beta = beta
        self.eps = eps
        
    def plot_alphas(self):
        plt.scatter(self.alpha1, self.alpha2, alpha=0.1)
        plt.xlabel(r'$\alpha_1$')
        plt.ylabel(r'$\alpha_2$')
        plt.xlim([0, 1])
        plt.ylim([0, 1])
        plt.grid()
        plt.show()
        
    def create_figure(self, P):
        self.calc_UP_A1_A2(P)
        alpha1pref = [alpha1 for alpha1 in np.linspace(0, self.UP/self.A1, 100)]
        alpha2pref = [self.UP/self.A2 - alpha1 * self.A1/self.A2
                      for alpha1 in alpha1pref]
        
        C = self.average_cost(P)
        alpha1cost = [alpha1 for alpha1 in np.linspace(0, C/self.L1, 100)]
        alpha2cost = [C/L2 - alpha1 * L1/L2 for alpha1 in alpha1cost]
        
        
        plt.scatter(self.alpha1, self.alpha2, alpha=0.1)
        plt.plot(alpha1pref, alpha2pref, label='isopreference')
        plt.plot(alpha1cost, alpha2cost, label='isocost')
        plt.xlabel(r'$\alpha_1$')
        plt.ylabel(r'$\alpha_2$')
        plt.grid()
        plt.legend()
        plt.show()
        
    def utility(self, x):
        return x**(1 - self.eps) / (1 - self.eps)
        
    def calc_UP_A1_A2(self, P):
        self.UP = self.beta * (self.utility(self.w) - self.utility(self.w - P))
        self.A1 = self.utility(self.w - P) - self.utility(self.w - self.L1) + self.UP
        self.A2 = self.utility(self.w - P) - self.utility(self.w - self.L2) + self.UP

    def participation(self, P):
        self.calc_UP_A1_A2(P)
        return self.alpha1 * self.A1 + self.alpha2 * self.A2 - self.UP > 0
        
    def average_cost(self, P):
        insured = self.participation(P)
        N = sum(insured * (self.alpha1 * self.L1 + self.alpha2 * self.L2))
        D = sum(insured)
        return N / (D + 1e-16)
    
    def check_propitious_selection(self):
        prices = np.arange(0, self.L1+1, 1000)
        average_costs = []
        old_cost = 0
        for price in prices:
            new_cost = self.average_cost(price)
            average_costs.append(new_cost)
            if new_cost < 1:
                return False
            if new_cost < old_cost:
                print(f'propitious selection for L1={L1} and L2={L2}!')
                return True
            old_cost = new_cost
    
    def find_prices_propitious_selection(self, step=100):
        prices = np.arange(0, self.L1+1, step)
        old_cost = 0
        prices_propitious = []
        for price in prices:
            new_cost = self.average_cost(price)
            if new_cost < 1:
                return prices_propitious
            if new_cost < old_cost:
                prices_propitious.append(price - step)
            old_cost = new_cost
            
    def plot_average_cost_and_profit(self, step=100):
        prices = np.arange(0, self.L1+1, step)
        average_costs = []
        profits = []
        old_cost = 0
        for price in prices:
            new_cost = self.average_cost(price)
            average_costs.append(new_cost)
            profit = sum(self.participation(price)) * (price - new_cost)
            profits.append(profit)
            if new_cost < 1:
                break
        fig, ax1 = plt.subplots()
        
        color = 'tab:red'
        ax1.set_xlabel('price')
        ax1.set_ylabel('average_cost', color=color)
        ax1.plot(prices[:len(average_costs)], average_costs, color=color)
        ax1.tick_params(axis='y', labelcolor=color)

        ax2 = ax1.twinx() 
        color = 'tab:blue'
        ax2.set_ylabel('profit', color=color)
        ax2.plot(prices[:len(profits)], profits, color=color)
        ax2.tick_params(axis='y', labelcolor=color)
        ax2.grid()

        fig.tight_layout()
        plt.show()
        
def plot_propitious_selection(l_propitious):
    L1s = [L1 for L1, L2 in l_propitious]
    L2s = [L2 for L1, L2 in l_propitious]

    plt.scatter(L1s, L2s)
    plt.xlabel('L1')
    plt.ylabel('L2')
    plt.xlim([0, 100e3])
    plt.ylim([0, 100e3])
    plt.grid()
    plt.show()

# %% [markdown]
# # Income

# %%
df = pd.read_excel("..\data\compas_enquete_mll.xlsx")
df.totincome.describe()
# Out:
# count    1.296000e+03
# mean     1.194043e+05
# std      5.568754e+05
# min      1.000000e+00
# 25%      4.500000e+04
# 50%      7.400000e+04
# 75%      1.050000e+05
# max      1.500000e+07
# Name: totincome, dtype: float64

# %% [markdown]
# # Using pr_nhome_compas

# %%
df.rename(columns={'pr_nhome_compas': 'alpha1',
                   'pr_alive_85_compas': 'pi'},
          inplace=True)

print(f'prob dependency before 85: {(df.alpha1 > df.pi).mean()}')
df['alpha2'] = (df.pi - df.alpha1).apply(lambda x: max(x, 0))
df['death'] = 1 - df.alpha1 - df.alpha2
df = df[['alpha1', 'alpha2', 'death']]
df.describe()
# Out:
# prob dependency before 85: 0.002
#             alpha1       alpha2        death
# count  2000.000000  2000.000000  2000.000000
# mean      0.262151     0.385839     0.352010
# std       0.112210     0.159902     0.119078
# min       0.055000     0.000000     0.125000
# 25%       0.167500     0.267500     0.260000
# 50%       0.255000     0.332500     0.340000
# 75%       0.350000     0.562500     0.425625
# max       0.522500     0.697500     0.892500

# %% [markdown]
# ## Find propitious selection

# %%
w = 100000

l_propitious_nhome = []
for L1 in np.arange(0, w + 1, 1000):
    for L2 in np.arange(0, L1, 1000):
        propitious = Propitious(w, df.alpha1, df.alpha2, L1, L2)
        if propitious.check_propitious_selection():
            l_propitious_nhome.append((L1, L2))
plot_propitious_selection(l_propitious_nhome)
# Out:
# propitious selection for L1=74000 and L2=69000!
# propitious selection for L1=78000 and L2=73000!
# propitious selection for L1=86000 and L2=55000!
# propitious selection for L1=86000 and L2=82000!
# propitious selection for L1=87000 and L2=55000!
# propitious selection for L1=91000 and L2=64000!
# propitious selection for L1=93000 and L2=62000!

# %% [markdown]
# ## Find prices for which there is propitious selection

# %%
for L1, L2 in l_propitious_nhome:
    propitious = Propitious(w, df.alpha1, df.alpha2, L1, L2)
    propitious_prices = propitious.find_prices_propitious_selection(step=50)
    print(f'L1={L1}, L2={L2}')
    print(propitious_prices)
# Out:
# L1=74000, L2=69000
# [65150, 65350, 65450, 65650, 65750, 65850]
# L1=78000, L2=73000
# [69000, 69100, 69200, 69250, 69400, 69500, 69700, 69850, 69950]
# L1=86000, L2=55000
# [69350, 70100, 70650, 70900]
# L1=86000, L2=82000
# [78200, 78400, 78500, 78600, 78800, 78900]
# L1=87000, L2=55000
# [57850, 60400, 70250, 71000, 71500, 71600, 71800]
# L1=91000, L2=64000
# [66850, 68100, 74750, 76050, 76650, 77250, 77650, 77700, 77950]
# L1=93000, L2=62000
# [63900, 65350, 65600, 66350, 78000, 78200, 79000, 79450, 79600, 79750]

# %% [markdown]
# ## Specific example of propitious selection

# %%
L1, L2 = l_propitious_nhome[6]
print(f'L1={L1}, L2={L2}')
propitious = Propitious(w, df.alpha1, df.alpha2, L1, L2)
for price in propitious.find_prices_propitious_selection(step=50):
    print(price)
    propitious.create_figure(price)
# Out:
# L1=93000, L2=62000
# 63900
# 65350
# 65600
# 66350
# 78000
# 78200
# 79000
# 79450
# 79600
# 79750

# %%
prices = np.arange(66000, 67000, step=50)
average_costs = [propitious.average_cost(P) for P in prices]
s = pd.Series(average_costs, index=prices)
s.plot(grid=True)
plt.show()

# %%
df = pd.read_excel("..\data\compas_enquete_mll.xlsx")
df.rename(columns={'pr_adl_compas': 'alpha1',
                   'pr_alive_85_compas': 'pi'},
          inplace=True)

df.totincome.describe()
# Out:
# count    1.296000e+03
# mean     1.194043e+05
# std      5.568754e+05
# min      1.000000e+00
# 25%      4.500000e+04
# 50%      7.400000e+04
# 75%      1.050000e+05
# max      1.500000e+07
# Name: totincome, dtype: float64

# %%
print(f'prob health issues before 85: {(df.alpha1 > df.pi).mean()}')
df['alpha2'] = (df.pi - df.alpha1).apply(lambda x: max(x, 0))
df['death'] = 1 - df_dep.alpha_1 - df_dep.alpha_2
df = df[['alpha1', 'alpha2', 'death']]
df.describe()
# Out:
# prob health issues before 85: 0.2145
#             alpha1       alpha2        death
# count  2000.000000  2000.000000  2000.000000
# mean      0.560815     0.105889     0.352010
# std       0.072414     0.096482     0.119078
# min       0.340000     0.000000     0.125000
# 25%       0.510000     0.012500     0.260000
# 50%       0.560000     0.080000     0.340000
# 75%       0.610000     0.197500     0.425625
# max       0.767500     0.335000     0.892500

# %% [markdown]
# # Using pr_adl_compas

# %%
df = pd.read_excel("..\data\compas_enquete_mll.xlsx")
df.rename(columns={'pr_adl_compas': 'alpha1',
                   'pr_alive_85_compas': 'pi'},
          inplace=True)

print(f'prob health issues before 85: {(df.alpha1 > df.pi).mean()}')
df['alpha2'] = (df.pi - df.alpha1).apply(lambda x: max(x, 0))
df['death'] = 1 - df.alpha1 - df.alpha2
df = df[['alpha1', 'alpha2', 'death']]
df.describe()
# Out:
# prob health issues before 85: 0.2145
#             alpha1       alpha2        death
# count  2000.000000  2000.000000  2000.000000
# mean      0.560815     0.105889     0.333296
# std       0.072414     0.096482     0.092854
# min       0.340000     0.000000     0.125000
# 25%       0.510000     0.012500     0.260000
# 50%       0.560000     0.080000     0.335000
# 75%       0.610000     0.197500     0.402500
# max       0.767500     0.335000     0.585000

# %% [markdown]
# ## Find propitious selection

# %%
w = 100000

l_propitious_adl = []
for L1 in np.arange(0, w + 1, 1000):
    for L2 in np.arange(0, L1, 1000):
        propitious = Propitious(w, df.alpha1, df.alpha2, L1, L2)
        if propitious.check_propitious_selection():
            l_propitious_adl.append((L1, L2))
plot_propitious_selection(l_propitious_adl)
# Out:
# propitious selection for L1=69000 and L2=49000!
# propitious selection for L1=70000 and L2=50000!
# propitious selection for L1=71000 and L2=51000!
# propitious selection for L1=72000 and L2=52000!
# propitious selection for L1=73000 and L2=53000!
# propitious selection for L1=74000 and L2=53000!
# propitious selection for L1=74000 and L2=55000!
# propitious selection for L1=75000 and L2=54000!
# propitious selection for L1=76000 and L2=55000!
# propitious selection for L1=79000 and L2=56000!
# propitious selection for L1=79000 and L2=59000!
# propitious selection for L1=79000 and L2=61000!
# propitious selection for L1=85000 and L2=69000!
# propitious selection for L1=86000 and L2=64000!
# propitious selection for L1=86000 and L2=65000!
# propitious selection for L1=86000 and L2=66000!
# propitious selection for L1=86000 and L2=67000!
# propitious selection for L1=86000 and L2=68000!
# propitious selection for L1=86000 and L2=69000!
# propitious selection for L1=86000 and L2=70000!
# propitious selection for L1=87000 and L2=66000!
# propitious selection for L1=87000 and L2=69000!
# propitious selection for L1=91000 and L2=70000!
# propitious selection for L1=91000 and L2=71000!
# propitious selection for L1=91000 and L2=72000!
# propitious selection for L1=91000 and L2=73000!
# propitious selection for L1=91000 and L2=74000!
# propitious selection for L1=91000 and L2=75000!
# propitious selection for L1=91000 and L2=76000!
# propitious selection for L1=92000 and L2=74000!
# propitious selection for L1=92000 and L2=76000!
# propitious selection for L1=94000 and L2=74000!
# propitious selection for L1=94000 and L2=75000!
# propitious selection for L1=94000 and L2=76000!
# propitious selection for L1=94000 and L2=77000!
# propitious selection for L1=94000 and L2=78000!
# propitious selection for L1=94000 and L2=79000!
# propitious selection for L1=94000 and L2=80000!
# propitious selection for L1=94000 and L2=81000!
# propitious selection for L1=96000 and L2=80000!
# propitious selection for L1=96000 and L2=81000!
# propitious selection for L1=96000 and L2=82000!
# propitious selection for L1=96000 and L2=83000!
# propitious selection for L1=96000 and L2=84000!

# %% [markdown]
# ## Find prices for which there is propitious selection

# %%
for L1, L2 in l_propitious_adl:
    propitious = Propitious(w, df.alpha1, df.alpha2, L1, L2)
    propitious_prices = propitious.find_prices_propitious_selection(step=50)
    print(f'L1={L1}, L2={L2}')
    print(propitious_prices)
# Out:
# L1=69000, L2=49000
# [57850, 58000, 58350, 59050, 59100, 59400, 59600, 59700, 59900, 59950]
# L1=70000, L2=50000
# [59800, 60050, 60100, 60250, 60400, 60700, 60900, 60950]
# L1=71000, L2=51000
# [60250, 60800, 61050, 61100, 61250, 61400, 61700, 61850, 61950]
# L1=72000, L2=52000
# [61250, 61800, 62050, 62100, 62250, 62400, 62900, 62950]
# L1=73000, L2=53000
# [62250, 63050, 63100, 63300, 63400, 63450, 63500, 63600, 63750, 63900, 63950]
# L1=74000, L2=53000
# [63000, 63200, 63250, 63500, 63800, 63950, 64100, 64300, 64400, 64500, 64650, 64850, 64900]
# L1=74000, L2=55000
# [63550, 63850, 64050, 64150, 64250, 64500, 64600, 64650, 64700, 64900, 64950, 65050]
# L1=75000, L2=54000
# [64050, 64300, 64500, 64600, 64950, 65100, 65300, 65350, 65400, 65550, 65650, 65850, 65950]
# L1=76000, L2=55000
# [65050, 65250, 65300, 65550, 65700, 65850, 66000, 66150, 66350, 66450, 66550, 66700, 66900, 66950]
# L1=79000, L2=56000
# [67950, 68050, 68300, 68400, 68650, 68900, 69200, 69250, 69350, 69450, 69600, 69950]
# L1=79000, L2=59000
# [68200, 68450, 69050, 69150, 69250, 69300, 69500, 69650, 69700, 69800, 69950, 70100, 70200]
# L1=79000, L2=61000
# [69000, 69100, 69350, 69450, 69900, 69950, 70200, 70350]
# L1=85000, L2=69000
# [75400, 75950, 76050, 76100, 76200, 76350, 76500, 76650, 76700, 76750, 76950]
# L1=86000, L2=64000
# [75000, 75100, 75750, 75800, 76000, 76200, 76500, 76700, 77000, 77050, 77250, 77350, 77700]
# L1=86000, L2=65000
# [73800, 75100, 75200, 75850, 75950, 76100, 76350, 76450, 76500, 76650, 76900, 77150, 77250, 77350, 77450, 77750, 77800]
# L1=86000, L2=66000
# [75800, 76200, 76500, 76550, 76650, 76900, 77000, 77100, 77250, 77300, 77350, 77450, 77600, 77800, 77850]
# L1=86000, L2=67000
# [76300, 76550, 76650, 77050, 77100, 77300, 77400, 77450, 77550, 77600, 77850, 77900]
# L1=86000, L2=68000
# [75700, 76300, 76700, 77000, 77050, 77100, 77200, 77250, 77450, 77550, 77600, 77650, 77850, 77900, 78000]
# L1=86000, L2=69000
# [76800, 76900, 77050, 77100, 77200, 77250, 77350, 77450, 77650, 77700, 77950, 78050]
# L1=86000, L2=70000
# [74900, 76450, 77050, 77200, 77250, 77350, 77450, 77650, 77800, 77850, 77900, 78050]
# L1=87000, L2=66000
# [77000, 77150, 77500, 77600, 77650, 78050, 78100, 78300, 78400, 78500, 78600, 78950]
# L1=87000, L2=69000
# [76900, 77400, 77700, 77850, 78000, 78150, 78250, 78600, 78700, 78750, 78800, 78950, 79050, 79150]
# L1=91000, L2=70000
# [80750, 81550, 81750, 81950, 82050, 82250, 82600, 82800, 82900, 83050, 83200, 83300, 83350, 83400, 83450, 83700, 83750]
# L1=91000, L2=71000
# [80750, 81150, 81350, 81650, 82100, 82200, 82400, 82700, 82900, 83000, 83200, 83300, 83350, 83450, 83500, 83800]
# L1=91000, L2=72000
# [82150, 82400, 82600, 82700, 82900, 83000, 83100, 83300, 83400, 83450, 83550, 83600, 83800, 83850]
# L1=91000, L2=73000
# [81150, 82000, 82450, 82750, 82850, 83000, 83100, 83150, 83450, 83500, 83700, 83850, 83900]
# L1=91000, L2=74000
# [80750, 81600, 81900, 82200, 82650, 82900, 83050, 83150, 83200, 83450, 83550, 83650, 83800, 83900, 84000]
# L1=91000, L2=75000
# [81950, 82150, 82850, 83150, 83300, 83350, 83400, 83650, 83700, 83900, 84050]
# L1=91000, L2=76000
# [82600, 83050, 83150, 83300, 83350, 83450, 83600, 83800, 84050, 84100]
# L1=92000, L2=74000
# [82400, 83000, 83350, 83450, 83550, 83700, 83750, 83950, 84000, 84100, 84250, 84350, 84450, 84500, 84650, 84750, 84850, 84950, 85100, 85200]
# L1=92000, L2=76000
# [83750, 84000, 84100, 84150, 84450, 84550, 84650, 84850, 84900, 84950, 85000, 85150, 85200, 85300]
# L1=94000, L2=74000
# [84750, 85750, 85800, 86100, 86200, 86300, 86550, 86750, 86900, 87050, 87200, 87300, 87400, 87700]
# L1=94000, L2=75000
# [85450, 85550, 85750, 85850, 85950, 86150, 86250, 86450, 86900, 87150, 87300, 87400, 87450, 87750]
# L1=94000, L2=76000
# [85600, 86300, 86600, 86750, 87050, 87100, 87300, 87400, 87550, 87800]
# L1=94000, L2=77000
# [84450, 85850, 86250, 86350, 86450, 86550, 86750, 86850, 87000, 87100, 87200, 87400, 87550, 87650, 87850]
# L1=94000, L2=78000
# [85750, 85950, 86350, 86550, 86750, 86900, 87000, 87200, 87250, 87500, 87550, 87650, 87750, 87850, 87950]
# L1=94000, L2=79000
# [86100, 86550, 86800, 87200, 87250, 87300, 87550, 87600, 87650, 87700, 87850, 87900, 88000]
# L1=94000, L2=80000
# [86150, 87000, 87050, 87100, 87250, 87300, 87500, 87700, 87750, 87950, 88050]
# L1=94000, L2=81000
# [86450, 86750, 87250, 87300, 87400, 87550, 87700, 87850, 87900, 88050]
# L1=96000, L2=80000
# [88850, 89300, 89550, 89800, 90100, 90150, 90300, 90400, 90450, 90550, 90750]
# L1=96000, L2=81000
# [89300, 89400, 89850, 89950, 90150, 90250, 90400, 90450, 90550, 90650, 90800, 90850]
# L1=96000, L2=82000
# [88250, 89700, 89850, 90050, 90100, 90250, 90300, 90400, 90500, 90550, 90650, 90800, 90900]
# L1=96000, L2=83000
# [89250, 90250, 90300, 90400, 90600, 90650, 90700, 90800, 90850, 90950]
# L1=96000, L2=84000
# [89300, 89800, 90100, 90150, 90300, 90450, 90550, 90700, 90750, 90950]

# %% [markdown]
# ## Specific example of propitious selection

# %%
# Out:
# (94000, 77000)

# %%
L1, L2 = l_propitious_adl[34]
print(f'L1={L1}, L2={L2}')
propitious = Propitious(w, df.alpha1, df.alpha2, L1, L2)
for price in propitious.find_prices_propitious_selection(step=50):
    print(price)
    propitious.create_figure(price)
# Out:
# L1=94000, L2=77000
# 84450
# 85850
# 86250
# 86350
# 86450
# 86550
# 86750
# 86850
# 87000
# 87100
# 87200
# 87400
# 87550
# 87650
# 87850

# %%
prices = np.arange(86000, 86500, step=50)
average_costs = [propitious.average_cost(P) for P in prices]
s = pd.Series(average_costs, index=prices)
s.plot(grid=True)
plt.show()
